# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from functions import ackley_plot, rastrigin_plot, schwefel_plot, rosenbrock_plot, levy_plot

# %%
ACKLEY_MIN_BOUND = -32
ACKLEY_MAX_BOUND = 32

RASTRIGIN_MIN_BOUND = -5
RASTRIGIN_MAX_BOUND = 5

SCHWEFEL_MIN_BOUND = -420
SCHWEFEL_MAX_BOUND = 420

ROSENBROCK_MIN_BOUND = -2
ROSENBROCK_MAX_BOUND = 2

LEVY_MIN_BOUND = -10
LEVY_MAX_BOUND = 10

# %%
MIN_BOUND = ACKLEY_MIN_BOUND
MAX_BOUND = ACKLEY_MAX_BOUND

# %%
X = np.arange(-32, 32, 0.25)
Y = np.arange(-32, 32, 0.25) #ackley

X = np.linspace(-5.12, 5.12, 100)     
Y = np.linspace(-5.12, 5.12, 100) #rastrigin

X = np.linspace(-420, 420, 100)  #schwefel   
Y = np.linspace(-420, 420, 100)

X = np.linspace(-2, 2, 100)  #rosenbrock   
Y = np.linspace(-2, 2, 100)

X = np.linspace(-10, 10, 100)  #levy   
Y = np.linspace(-10, 10, 100)

X, Y = np.meshgrid(X, Y)

# %%
Z = levy_plot([X, Y])

# %%
fig = plt.figure(figsize=(15,10))

axis = fig.gca(projection='3d')
axis.plot_surface(X[:len(X)-1], Y[:len(X)-1], Z, cmap='jet')

plt.show()
